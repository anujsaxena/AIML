# %% [markdown]
# <a href="https://colab.research.google.com/github/anujsaxena/AIML/blob/main/AIML_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Audio and Image processing**

# %%
# !pip install gtts

# %%
# !pip install pyttsx3

# %%
import spacy
from gtts import gTTS
from IPython.display import Audio
language = 'en'
nlp = spacy.load("en_core_web_sm")

# %%
txt =''' The Omicron variant of COVID-19 that was first identified in South Africa in late November 2021 
has since spread across the globe and cases have been reported from 171 countries, the World Health Organisation (WHO) said.
In its latest technical brief, the global health body said that Omicron is soon set to replace Delta globally as a result of 
its immunity evading potential.'''

doc = nlp(txt)

for i, sent in enumerate(doc.sents, 1):
  print(sent)
  tts = gTTS(str(sent))  #convert to string and provide it to convert into speech
  tts.save('covid.wav')
  soundfile = 'covid.wav'
  Audio(soundfile, autoplay=True)
# Out:
#  The Omicron variant of COVID-19 that was first identified in South Africa in late November 2021
# has since spread across the globe and cases have been reported from 171 countries, the World Health Organisation (WHO) said.
#
# In its latest technical brief, the global health body said that Omicron is soon set to replace Delta globally as a result of
# its immunity evading potential.

# %% [markdown]
# # **Install ThinkDSP**

# %%
# !git clone https://github.com/AllenDowney/ThinkDSP.git
# Out:
# Cloning into 'ThinkDSP'...
# remote: Enumerating objects: 2469, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 2469 (delta 23), reused 20 (delta 9), pack-reused 2421
# Receiving objects: 100% (2469/2469), 215.71 MiB | 13.70 MiB/s, done.
# Resolving deltas: 100% (1343/1343), done.
# Checking out files: 100% (302/302), done.

# %%
import sys
sys.path.insert(0, 'ThinkDSP/code/') 
import thinkdsp
import matplotlib.pyplot as pyplot
import IPython

# %%
#Generate wave
sin = thinkdsp.SinSignal(freq=400, amp=0.5) # Where freq is the frequency and amp is the amplitude of the sine wave
wave = sin.make_wave(duration=2, start=0, framerate=44100) # Turn the sin wave into an audio wave

# Plot wave
period = sin.period
segment = wave.segment(start=0, duration=period*3)
segment.plot()
pyplot.show()

# Play wave
wave.play()
IPython.display.Audio('covid.wav') # This is required on Google Colab due to compatibility issues
# Out:
# Writing sound.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# https://colab.research.google.com/github/Tyler-Hilbert/AudioProcessingInPythonWorkshop/blob/master/AudioProcessingInPython.ipynb
#
# Librosa
# https://pypi.org/project/librosa/
#
# https://analyticsindiamag.com/hands-on-tutorial-on-visualizing-spectrograms-in-python/

# %%
# !pip install opencv-python

# %%
import cv2
from matplotlib import pyplot as plt

#rread an image
img = cv2.imread('image.jpg')
# OpenCV opens images as BRG 
# but we want it as RGB We'll 
# also need a grayscale version
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#display the image
# Creates the environment 
# of the picture and shows it
#plt.subplot(1, 1, 1)
plt.imshow(img_rgb)
plt.show()

# Use minSize because for not 
# bothering with extra-small 
# dots that would look like STOP signs

stop_data = cv2.CascadeClassifier('stop_data.xml')
found = stop_data.detectMultiScale(img_gray, minSize =(30, 30))

amount_found = len(found) #if image is found lenght will be more than 0

print(amount_found)

if amount_found != 0:
   # There may be more than one
    # sign in the image
    for (x, y, width, height) in found:
          
        # We draw a green rectangle around
        # every recognized sign
        cv2.rectangle(img_rgb, (x, y), (x + height, y + width), (0, 255, 0), 10)
          
# Creates the environment of 
# the picture and shows it

plt.imshow(img_rgb)
plt.show()
# Out:
# 1

# %% [markdown]
# https://github.com/andrewssobral/vehicle_detection_haarcascades

# %% [markdown]
# https://medium.com/programming-fever/license-plate-recognition-using-opencv-python-7611f85cdd6c

# %%
import cv2

# Create the haar cascade
faceCascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
# Read the image
image = cv2.imread('abba.png')
plt.imshow(image)
plt.show()

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# Detect faces in the image

# Draw a rectangle around the faces

faces = faceCascade.detectMultiScale(
   gray,
   scaleFactor=1.1,
   minNeighbors=5,
   minSize=(30, 30),
   flags = cv2.CASCADE_SCALE_IMAGE #flags = cv2.cv.CV_HAAR_SCALE_IMAGE
)
print("Found {0} faces!".format(len(faces)))

# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
plt.imshow(image)
plt.show()
# Out:
# Found 4 faces!

# %%
import cv2

# Create the haar cascade
faceCascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
# Read the image
image = cv2.imread('image_1.jpg')
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#display the image
# Creates the environment 
# of the picture and shows it
#plt.subplot(1, 1, 1)
plt.imshow(img_rgb)
plt.show()

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# Detect faces in the image

# Draw a rectangle around the faces

faces = faceCascade.detectMultiScale(
   gray,
   scaleFactor=1.1,
   minNeighbors=5,
   minSize=(30, 30),
   flags = cv2.CASCADE_SCALE_IMAGE #flags = cv2.cv.CV_HAAR_SCALE_IMAGE
)
print("Found {0} faces!".format(len(faces)))

# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
plt.imshow(image)
plt.show()
# Out:
# Found 4 faces!
